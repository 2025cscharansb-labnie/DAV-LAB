# %% [markdown]
# <a href="https://colab.research.google.com/github/2025cscharansb-labnie/DAV-LAB/blob/main/Program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "student_ID" : [101, 102, 103, 104, 105, 106, 102, 107],
    "Student" : ["Asha" , "Ravi","Priya","John","Anu","Kiran","Ravi","Meena"],
    "Department" : ["CSE","CSE","ECE","ECE","CSE","EEE","CSE","EEE"],
    "Attendence" : [90,75,95,60,80,70,75,85],
    "Internal_Marks" : [85,70,90,55,78,65,70,None],
    "Final_Marks" : [88,72,92,50,80,68,72,82]
}

# %%
df = pd.DataFrame(data)
df.to_csv("student.csv", index = False)
print("Student.csv created sucessfully!")
# Out:
# Student.csv created sucessfully!

# %%
df = pd.read_csv("student.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\nFirst Five Records:")
print(df.head())
# Out:
# First Five Records:
#    student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80

# %%
print("\nLast Five Records: ")
print(df.tail())
# Out:
# Last Five Records:
#    student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\n Dataset shape:")
print(df.shape)
# Out:
#  Dataset shape:
# (8, 6)

# %%
print("\ncheck datatypes:")
df.dtypes
# Out:
# check datatypes:
# student_ID          int64
# Student            object
# Department         object
# Attendence          int64
# Internal_Marks    float64
# Final_Marks         int64
# dtype: object

# %%
print("\nDescriptive Statistics:")
df.describe()
# Out:
# Descriptive Statistics:
#        student_ID  Attendence  Internal_Marks  Final_Marks
# count     8.00000    8.000000        7.000000     8.000000
# mean    103.75000   78.750000       73.285714    75.500000
# std       2.12132   11.259916       11.996031    13.212548
# min     101.00000   60.000000       55.000000    50.000000
# 25%     102.00000   73.750000       67.500000    71.000000
# 50%     103.50000   77.500000       70.000000    76.000000
# 75%     105.25000   86.250000       81.500000    83.500000
# max     107.00000   95.000000       90.000000    92.000000

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# student_ID        0
# Student           0
# Department        0
# Attendence        0
# Internal_Marks    1
# Final_Marks       0
# dtype: int64

# %%
print("\nNumber of Duplicate Records:")
print(df.duplicated().sum())
# Out:
# Number of Duplicate Records:
# 1

# %%
print("\nAverage Final Marks by Department:")
print(df.groupby("Department")["Final_Marks"].mean())
# Out:
# Average Final Marks by Department:
# Department
# CSE    78.0
# ECE    71.0
# EEE    75.0
# Name: Final_Marks, dtype: float64

# %%
courses = pd.DataFrame({
    "Student_ID" : [101,102,103,104,105,106,107],
    "course":["Python","Java","C++","JavaScript","Matlab","Rust","SQL"]

})

# %%
merge_df = pd.merge(
    df,
    courses,
    on="Student_ID"
)
print("\nMerged Dataset:")
print(merged_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5396/2964111745.py in <cell line: 0>()
# ----> 1 merge_df = pd.merge(
#       2     df,
#       3     courses,
#       4     on="Student_ID"
#       5 )
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'Student_ID'
